# %% [markdown]
# # YOLOv8-Container detection

# %%
from ultralytics import YOLO
 
  Load the model.
 model = YOLO('yolov8n.pt')
 
  Training.
  results = model.train(
    data='path to dataset\data.yaml',    
    imgsz=640,
    epochs=100,
   batch=8,
 )

# %% [markdown]
# ## Loading Container pre-trained model

# %%
from ultralytics import YOLO
model = YOLO('weight_path\')

# %% [markdown]
# ## Prediction(1)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 480x640 18 Containers, 113.7ms
# Speed: 4.0ms preprocess, 113.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict6

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict6/co1.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=457x339>

# %% [markdown]
# ## Prediction(2)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 384x640 75 Containers, 115.7ms
# Speed: 5.0ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict7

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict7/co5.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=901x516>

# %% [markdown]
# ## Prediction(3)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 416x640 39 Containers, 127.7ms
# Speed: 10.0ms preprocess, 127.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs\detect\predict7

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict7/co10.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=843x515>
